# %%
import pandas as pd
data = [['apple',10,20],['orange',15,150],['grapes',14,80],['pineapple',10,40]]
df1 = pd.DataFrame(data, columns = ['Fruit_name','Quantity','Unit_Price'])
df1
# Out:
#   Fruit_name  Quantity  Unit_Price
# 0      apple        10          20
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          40

# %%
import pandas as pd
data = {'Fruit_Name':['apple','orange','grapes','pineapple'],'Quantity':[10,15,14,10],'Unit_Price':[20,150,80,40]}
df2 = pd.DataFrame(data)
df2
# Out:
#   Fruit_Name  Quantity  Unit_Price
# 0      apple        10          20
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          40

# %%
import pandas as pd
data = {'BP':[120,160,170,130,140,155,160,142,136,102],'GL':[100,200,250,110,120,180,220,108,112,100],'HR':[76,120,132,82,90,112,108,92,90,82],'Heart_Disease':['No','Yes','Yes','No','No','Yes','Yes','No','No','No']}
df3 = pd.DataFrame(data)
df3
# Out:
#     BP   GL   HR Heart_Disease
# 0  120  100   76            No
# 1  160  200  120           Yes
# 2  170  250  132           Yes
# 3  130  110   82            No
# 4  140  120   90            No
# 5  155  180  112           Yes
# 6  160  220  108           Yes
# 7  142  108   92            No
# 8  136  112   90            No
# 9  102  100   82            No

# %%
import pandas as pd
data = [['apple',10,20],['orange',15,150],['grapes',14,80],['pineapple',10,40]]
df4 = pd.DataFrame(data,index=['f1','f2','f3','f4'], columns = ['Fruit_name','Quantity','Unit_Price'])
df4
# Out:
#    Fruit_name  Quantity  Unit_Price
# f1      apple        10          20
# f2     orange        15         150
# f3     grapes        14          80
# f4  pineapple        10          40

# %%
data = [['apple',10,20],['orange',15,150],['grapes',14,80],['pineapple',10,40]]
data
# Out:
# [['apple', 10, 20],
#  ['orange', 15, 150],
#  ['grapes', 14, 80],
#  ['pineapple', 10, 40]]

# %%
import pandas as pd
iris = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names = ['sepal_length','petal_length','petal_width','class']
df5 = pd.read_csv(iris,sep = ',',names = names)
df5
# Out:
#      sepal_length  petal_length  petal_width           class
# 5.1           3.5           1.4          0.2     Iris-setosa
# 4.9           3.0           1.4          0.2     Iris-setosa
# 4.7           3.2           1.3          0.2     Iris-setosa
# 4.6           3.1           1.5          0.2     Iris-setosa
# 5.0           3.6           1.4          0.2     Iris-setosa
# ..            ...           ...          ...             ...
# 6.7           3.0           5.2          2.3  Iris-virginica
# 6.3           2.5           5.0          1.9  Iris-virginica
# 6.5           3.0           5.2          2.0  Iris-virginica
# 6.2           3.4           5.4          2.3  Iris-virginica
# 5.9           3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
df5.head()
df5.info()
df5.describe()
df5['class'].value_counts()
df5['class'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 150 entries, 5.1 to 5.9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   petal_length  150 non-null    float64
#  2   petal_width   150 non-null    float64
#  3   class         150 non-null    object
# dtypes: float64(3), object(1)
# memory usage: 5.9+ KB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ae9420e02e7c> in <module>
#       4 df5['class'].value_counts()
#       5 df5['class'].unique()
# ----> 6 dup
#
# NameError: name 'dup' is not defined

# %%
import matplotlib as plt
df5.plot()

# %%
import pandas as pd
import matplotlib.pyplot as
